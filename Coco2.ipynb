# %%
# %matplotlib inline
import time
import random
import pylab as pl
from IPython import display
from itertools import compress
import numpy as np
from Agente_A_Star import AgenteAStar


#Tamaño del tamblero
tam = 5
#Colores de los jugadores
ganar = 10
puntaje = [0,0]
turnos = 30
colors = ["#ffc0f7","red"]

#Parametros de la grafica
xmax = tam + tam/2
xmin = -tam - tam/2
ymax = tam-1 + 0.5
ymin = -0.5
pl.xlim(xmin, xmax)
pl.ylim(ymin, ymax)

#Tamaño de los cuadrados
size = (1)**(2)

class Tablero:
    def __init__(self,name,jugador):
        self.__name = name
        self.__estrellita = np.random.randint(tam**2)
        self.__tablero = np.zeros((tam,tam))
        self.__jugador = jugador
        indices = Pos1Dto2D(self.__estrellita-1,tam)
        self.__tablero[indices[0],indices[1]]=1
        if jugador == 1:
            self.InitPos1()
        else:
            self.InitPos2()
    def InitPos2(self):
        x1 = list(range(1,tam+1))
        for i in range(tam-1):
            x_aux1 = x1[-tam:]
            x1 = x1 + x_aux1
        y1 = []
        cont = tam-1
        for i in range(tam):
            for j in range(tam):
                y1 = y1 + [cont]
            cont -= 1
        self.x = x1
        self.y = y1
    def InitPos1(self):
        x2 = list(range(-tam,0))
        for i in range(tam-1):
            x_aux2 = x2[-tam:]
            x2 = x2 + x_aux2
        y2 = []
        cont = tam-1
        for i in range(tam):
            for j in range(tam):
                y2 = y2 + [cont]
            cont -= 1
        self.x = x2
        self.y = y2
    def PosEstrellita(self):
        return self.__estrellita
    def Jugador(self):
        return self.__jugador
    def DistanciaEstrellita(self,pos):
        pos = Pos1Dto2D(pos-1,tam)
        posEstrellita = np.nonzero(self.__tablero)
        return (abs(pos[0]-posEstrellita[0])+abs(pos[1]-posEstrellita[1]))[0]
    def __ActualizarTablero(self):
        self.__tablero = np.zeros((tam,tam))
        indices = Pos1Dto2D(self.__estrellita,tam)
        self.__tablero[indices[0],indices[1]]=1
    def Mover(self,direccion):
        ind = list(Pos1Dto2D(self.__estrellita,tam))
        if direccion == 1:
            ind[0] -= 1
            if ind[0] >= 0:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        elif direccion == 3:
            ind[0] += 1
            if ind[0] < tam:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        elif direccion == 4:
            ind[1] -= 1
            if ind[1] >= 0:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        elif direccion == 2:
            ind[1] += 1
            if ind[1] < tam:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        self.__ActualizarTablero()
        return self.__estrellita
    def Disparo(self,pos):
        if pos-1 == self.__estrellita:
            return 1
        else:
            return 0
    
class Sensor:
    def __init__(self):
        self.__P = [[0.70, 0.15, 0.1, 0.05],
                    [0.17, 0.6, 0.17, 0.06],
                    [0.06, 0.17, 0.6, 0.17],
                    [0.05, 0.12, 0.23, 0.6],
                    [0.03, 0.07, 0.1, 0.8]]
        self.__colors = ["verde", "amarillo", "anaranjado", "rojo"]
        self.colorsG = {"verde":"g", "amarillo":"#fff46f", "anaranjado":"#ff8b00", "rojo":"r"}
    def Sensar(self,dist):
        if dist > 4:
            dist = 4
        probs = self.__P[dist]
        alea = np.random.rand(1)[0]
        cont = 0
        while alea > 0:
            color = self.__colors[cont]
            alea -= probs[cont]
            cont += 1
        return color
    
def Pos2Dto1D(posX,posY,n):
    #pos inicia en 0
    pos1D = posX*n+posY
    return pos1D
def Pos1Dto2D(pos,n):
    indices = np.unravel_index(pos, (n,n))
    return indices
def UnoPorDim(mat,dim):
    maximos = mat.max(axis=dim)
    if np.sum(maximos) == tam:
        return True
    else:
        return False
    
#AGENTE DE PRUEBA
def Agente(a,b,c,d):
    acc = np.random.randint(3)+1
    if acc == 3:
        param = np.random.randint(4)+1
    else:
        param = np.random.randint(25)+1
    return acc, param


#AGENTES DE LOS ESTUDIANTES
    
    
#Ciclo general del juego, debera ser un while mientras nadie haya ganado o 121 iteraciones
jugadorActual = 1 #inicializacion del jugador
tableros = [Tablero("tablero1",1), Tablero("tablero2",2)]
sensor = Sensor()
resultado_accion = [None,None]
accion_oponente = [[None,None,None],[None,None,None]]

agente1 = AgenteAStar()
agente2 = AgenteAStar()


for i in range(turnos*2):

    #ASI VA A SER COMO SE LLAMA AL AGENTE DE CADA UNO
    if jugadorActual == 1:
        print("Agente",jugadorActual,"")
        start = time.time()

         #Para efectos del ejemplo genera una accion aleatoria, esta puede repetir lugar porque esta comentada la parte que lo chequea

        [tipoAccion, parametroAccion] = agente1.get_action_to_take(jugadorActual, resultado_accion[jugadorActual-1], accion_oponente[jugadorActual-1], tableros[jugadorActual-1].PosEstrellita())
        print(tipoAccion, ",", parametroAccion)
        end = time.time()
    else:
        print("Agente",jugadorActual,"")
        start = time.time()

         #Para efectos del ejemplo genera una accion aleatoria, esta puede repetir lugar porque esta comentada la parte que lo chequea

        [tipoAccion, parametroAccion] = agente2.get_action_to_take(jugadorActual, resultado_accion[jugadorActual-1], accion_oponente[jugadorActual-1], tableros[jugadorActual-1].PosEstrellita())
        
        print(tipoAccion, ",", parametroAccion)
        end = time.time()
    
    
    #Actualizacion del estado del tablero
    if tipoAccion == 1:
        puntos = tableros[jugadorActual%2].Disparo(parametroAccion)
        resultado_accion[jugadorActual-1] = puntos
        puntaje[jugadorActual-1] += puntos
        accion_oponente[jugadorActual%2] = [tipoAccion, parametroAccion, puntos]
        
            #Actualizacion del grafico
        pl.cla()
        pl.scatter(tableros[jugadorActual-1].x,tableros[jugadorActual-1].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[jugadorActual%2].x,tableros[jugadorActual%2].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[0].x[tableros[0].PosEstrellita()],tableros[0].y[tableros[0].PosEstrellita()], marker='*', s=size*500, color='#ffd800')
        pl.scatter(tableros[1].x[tableros[1].PosEstrellita()],tableros[1].y[tableros[1].PosEstrellita()], marker='*', s=size*500, color='#c0fcff')
        pl.scatter(tableros[jugadorActual%2].x[parametroAccion-1],tableros[jugadorActual%2].y[parametroAccion-1], marker='X', s=size*450, color=colors[puntos])
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print("Tiempo Agente",jugadorActual," :",end - start)
        
    elif tipoAccion == 2:
        dist = tableros[jugadorActual%2].DistanciaEstrellita(parametroAccion)
        colorSens = sensor.Sensar(dist)
        resultado_accion[jugadorActual-1] = colorSens
        accion_oponente[jugadorActual%2] = [tipoAccion, parametroAccion, colorSens]
        
        #Actualizacion del grafico
        pl.cla()
        pl.scatter(tableros[jugadorActual-1].x,tableros[jugadorActual-1].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[jugadorActual%2].x,tableros[jugadorActual%2].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[0].x[tableros[0].PosEstrellita()],tableros[0].y[tableros[0].PosEstrellita()], marker='*', s=size*500, color='#ffd800')
        pl.scatter(tableros[1].x[tableros[1].PosEstrellita()],tableros[1].y[tableros[1].PosEstrellita()], marker='*', s=size*500, color='#c0fcff')
        pl.scatter(tableros[jugadorActual%2].x[parametroAccion-1],tableros[jugadorActual%2].y[parametroAccion-1], marker='o', s=size*450, color=sensor.colorsG[colorSens])
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print("Tiempo Agente",jugadorActual," :",end - start)
        
    elif tipoAccion == 3:
        tableros[jugadorActual-1].Mover(parametroAccion)
        resultado_accion[jugadorActual-1] = None
        accion_oponente[jugadorActual%2] = [tipoAccion, None, None]
        
        pl.cla()
        pl.scatter(tableros[jugadorActual-1].x,tableros[jugadorActual-1].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[jugadorActual%2].x,tableros[jugadorActual%2].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[0].x[tableros[0].PosEstrellita()],tableros[0].y[tableros[0].PosEstrellita()], marker='*', s=size*500, color='#ffd800')
        pl.scatter(tableros[1].x[tableros[1].PosEstrellita()],tableros[1].y[tableros[1].PosEstrellita()], marker='*', s=size*500, color='#c0fcff')
        
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print("Tiempo Agente",jugadorActual," :",end - start)
    
    print("TURNO: ",i)
    print(accion_oponente)
    time.sleep(1)


    #ACA SE CHEQUEARIA SI ALGUIEN GANO
    if jugadorActual == 1:
        if puntaje[0] >= ganar:
            print("GANO JUGADOR 1")
    else:
        if puntaje[1] >= ganar:
            print("GANO JUGADOR 2")

    #Cambio de jugados
    if (i+1)%2 == 0:
        jugadorActual = 1
    else:
        jugadorActual = 2
print("PUNTAJE FINAL: ", puntaje)
# Out:
# Agente 1
# 2 , 21
# Tiempo Agente 1  : 0.0005948543548583984
# TURNO:  0
# [[None, None, None], [2, 21, 'verde']]
# Agente 2
# 2 , 16
# Tiempo Agente 2  : 0.0005879402160644531
# TURNO:  1
# [[2, 16, 'rojo'], [2, 21, 'verde']]
# Agente 1
# 1 , 21
# Tiempo Agente 1  : 0.0015339851379394531
# TURNO:  2
# [[2, 16, 'rojo'], [1, 21, 0]]
# Agente 2
# 3 , 1
# Tiempo Agente 2  : 0.0008788108825683594
# TURNO:  3
# [[3, None, None], [1, 21, 0]]
# Agente 1
# 1 , 17
# Tiempo Agente 1  : 0.0014600753784179688
# TURNO:  4
# [[3, None, None], [1, 17, 1]]
# Agente 2
# 3 , 1
# Tiempo Agente 2  : 0.00031304359436035156
# TURNO:  5
# [[3, None, None], [1, 17, 1]]
# Agente 1
# 1 , 12
# Tiempo Agente 1  : 0.015703201293945312
# TURNO:  6
# [[3, None, None], [1, 12, 1]]
# Agente 2
# 3 , 1
# Tiempo Agente
#  2  : 0.000576019287109375
# TURNO:  7
# [[3, None, None], [1, 12, 1]]
# Agente 1
# 1 , 11
# Tiempo Agente 1  : 0.01248478889465332
# TURNO:  8
# [[3, None, None], [1, 11, 0]]
# Agente 2
# 2 , 9
# Tiempo Agente 2  : 0.0006659030914306641
# TURNO:  9
# [[2, 9, 'amarillo'], [1, 11, 0]]
# Agente 1
# 1 , 8
# Tiempo Agente 1  : 0.012245893478393555
# TURNO:  10
# [[2, 9, 'amarillo'], [1, 8, 0]]
# Agente 2
# 3 , 3
# Tiempo Agente 2  : 0.0010528564453125
# TURNO:  11
# [[3, None, None], [1, 8, 0]]
# Agente 1
# 1 , 17
# Tiempo Agente 1  : 0.01192617416381836
# TURNO:  12
# [[3, None, None], [1, 17, 0]]
# Agente 2
# 3 , 1
# Tiempo Agente 2  : 0.0006492137908935547
# TURNO:  13
# [[3, None, None], [1, 17, 0]]
# Agente 1
# 1 , 6
# Tiempo Agente 1  : 0.010083198547363281
# TURNO:  14
# [[3, None, None], [1, 6, 0]]
# Agente 2
# 3 , 2
# Tiempo Agente 2  : 0.0006411075592041016
# TURNO:  15
# [[3, None, None], [1, 6, 0]]
# Agente 1
# 1 , 13
# Tiempo Agente 1  : 0.011937141418457031
# TURNO:  16
# [[3, None, None], [1, 13, 0]]
# Agente 2
# 3 , 2
# Tiempo Agente 2  : 0.0006430149078369141
# TURNO:  17
# [[3, None, None], [1, 13, 0]]
# Agente 1
# 2 , 2
# Tiempo Agente 1  : 0.012989997863769531
# TURNO:  18
# [[3, None, None], [2, 2, 'rojo']]
# Agente 2
# 1 , 8
# Tiempo Agente 2  : 0.0006892681121826172
# TURNO:  19
# [[1, 8, 0], [2, 2, 'rojo']]
# Agente 1
# 1 , 23
# Tiempo Agente 1  : 0.014027118682861328
# TURNO:  20
# [[1, 8, 0], [1, 23, 0]]
# Agente 2
# 2 , 9
# Tiempo Agente 2  : 0.001135110855102539
# TURNO:  21
# [[2, 9, 'rojo'], [1, 23, 0]]
# Agente 1
# 1 , 16
# Tiempo Agente 1  : 0.014014005661010742
# TURNO:  22
# [[2, 9, 'rojo'], [1, 16, 0]]
# Agente 2
# 2 , 20
# Tiempo Agente 2  : 0.000988006591796875
# TURNO:  23
# [[2, 20, 'verde'], [1, 16, 0]]
# Agente 1
# 1 , 19
# Tiempo Agente 1  : 0.013736248016357422
# TURNO:  24
# [[2, 20, 'verde'], [1, 19, 0]]
# Agente 2
# 1 , 20
# Tiempo Agente 2  : 0.0010311603546142578
# TURNO:  25
# [[1, 20, 0], [1, 19, 0]]
# Agente 1
# 3 , 4
# Tiempo Agente 1  : 0.01285696029663086
# TURNO:  26
# [[1, 20, 0], [3, None, None]]
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.0010480880737304688
# TURNO:  27
# [[1, 24, 1], [3, None, None]]
# Agente 1
# 3 , 1
# Tiempo Agente 1  : 0.0005788803100585938
# TURNO:  28
# [[1, 24, 1], [3, None, None]]
# Agente 2
# 1 , 23
# Tiempo Agente 2  : 0.016251325607299805
# TURNO:  29
# [[1, 23, 0], [3, None, None]]
# Agente 1
# 1 , 12
# Tiempo Agente 1  : 0.0007290840148925781
# TURNO:  30
# [[1, 23, 0], [1, 12, 0]]
# Agente 2
# 1 , 20
# Tiempo Agente 2  : 0.014778852462768555
# TURNO:  31
# [[1, 20, 0], [1, 12, 0]]
# Agente 1
# 3 , 1
# Tiempo Agente 1  : 0.013262748718261719
# TURNO:  32
# [[1, 20, 0], [3, None, None]]
# Agente 2
# 1 , 18
# Tiempo Agente 2  : 0.013990163803100586
# TURNO:  33
# [[1, 18, 0], [3, None, None]]
# Agente 1
# 1 , 23
# Tiempo Agente 1  : 0.0006718635559082031
# TURNO:  34
# [[1, 18, 0], [1, 23, 0]]
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.015124320983886719
# TURNO:  35
# [[1, 24, 0], [1, 23, 0]]
# Agente 1
# 1 , 14
# Tiempo Agente 1  : 0.012518167495727539
# TURNO:  36
# [[1, 24, 0], [1, 14, 0]]
# Agente 2
# 3 , 4
# Tiempo Agente 2  : 0.013522863388061523
# TURNO:  37
# [[3, None, None], [1, 14, 0]]
# Agente 1
# 1 , 17
# Tiempo Agente 1  : 0.012202978134155273
# TURNO:  38
# [[3, None, None], [1, 17, 0]]
# Agente 2
# 2 , 15
# Tiempo Agente 2  : 0.0006780624389648438
# TURNO:  39
# [[2, 15, 'rojo'], [1, 17, 0]]
# Agente 1
# 1 , 8
# Tiempo Agente 1  : 0.011662006378173828
# TURNO:  40
# [[2, 15, 'rojo'], [1, 8, 1]]
# Agente 2
# 3 , 2
# Tiempo Agente 2  : 0.013569116592407227
# TURNO:  41
# [[3, None, None], [1, 8, 1]]
# Agente 1
# 1 , 7
# Tiempo Agente 1  : 0.010029077529907227
# TURNO:
#  42
# [[3, None, None], [1, 7, 0]]
# Agente 2
# 2 , 17
# Tiempo Agente 2  : 0.0005540847778320312
# TURNO:  43
# [[2, 17, 'anaranjado'], [1, 7, 0]]
# Agente 1
# 1 , 8
# Tiempo Agente 1  : 0.01048898696899414
# TURNO:  44
# [[2, 17, 'anaranjado'], [1, 8, 0]]
# Agente 2
# 3 , 3
# Tiempo Agente 2  : 0.013559103012084961
# TURNO:  45
# [[3, None, None], [1, 8, 0]]
# Agente 1
# 1 , 9
# Tiempo Agente 1  : 0.010500907897949219
# TURNO:  46
# [[3, None, None], [1, 9, 0]]
# Agente 2
# 3 , 3
# Tiempo Agente 2  : 0.0005748271942138672
# TURNO:  47
# [[3, None, None], [1, 9, 0]]
# Agente 1
# 1 , 10
# Tiempo Agente 1  : 0.01121211051940918
# TURNO:  48
# [[3, None, None], [1, 10, 0]]
# Agente 2
# 1 , 23
# Tiempo Agente 2  : 0.0004799365997314453
# TURNO:  49
# [[1, 23, 0], [1, 10, 0]]
# Agente 1
# 1 , 19
# Tiempo Agente 1  : 0.01216578483581543
# TURNO:  50
# [[1, 23, 0], [1, 19, 1]]
# Agente 2
# 3 , 1
# Tiempo Agente 2  : 0.013892173767089844
# TURNO:  51
# [[3, None, None], [1, 19, 1]]
# Agente 1
# 1 , 18
# Tiempo Agente 1  : 0.014521121978759766
# TURNO:  52
# [[3, None, None], [1, 18, 0]]
# Agente 2
# 1 , 17
# Tiempo Agente 2  : 0.0006849765777587891
# TURNO:  53
# [[1, 17, 0], [1, 18, 0]]
# Agente 1
# 1 , 19
# Tiempo Agente 1  : 0.016849994659423828
# TURNO:  54
# [[1, 17, 0], [1, 19, 0]]
# Agente 2
# 3 , 1
# Tiempo Agente 2  : 0.012858152389526367
# TURNO:  55
# [[3, None, None], [1, 19, 0]]
# Agente 1
# 1 , 20
# Tiempo Agente 1  : 0.015099048614501953
# TURNO:  56
# [[3, None, None], [1, 20, 0]]
# Agente 2
# 1 , 13
# Tiempo Agente 2  : 0.0009059906005859375
# TURNO:  57
# [[1, 13, 0], [1, 20, 0]]
# Agente 1
# 3 , 1
# Tiempo Agente 1  : 0.015192270278930664
# TURNO:  58
# [[1, 13, 0], [3, None, None]]
# Agente 2
# 2 , 16
# Tiempo Agente 2  : 0.013303041458129883
# TURNO:  59
# [[2, 16, 'rojo'], [3, None, None]]
# PUNTAJE FINAL:  [4, 1]
