# %%
# %matplotlib inline
import time
import random
import pylab as pl
from IPython import display
from itertools import compress
import numpy as np
from Agente_A_Star import AgenteAStar


#Tamaño del tamblero
tam = 5
#Colores de los jugadores
ganar = 10
puntaje = [0,0]
turnos = 30
colors = ["#ffc0f7","red"]

#Parametros de la grafica
xmax = tam + tam/2
xmin = -tam - tam/2
ymax = tam-1 + 0.5
ymin = -0.5
pl.xlim(xmin, xmax)
pl.ylim(ymin, ymax)

#Tamaño de los cuadrados
size = (1)**(2)

class Tablero:
    def __init__(self,name,jugador):
        self.__name = name
        self.__estrellita = np.random.randint(tam**2)
        self.__tablero = np.zeros((tam,tam))
        self.__jugador = jugador
        indices = Pos1Dto2D(self.__estrellita-1,tam)
        self.__tablero[indices[0],indices[1]]=1
        if jugador == 1:
            self.InitPos1()
        else:
            self.InitPos2()
    def InitPos2(self):
        x1 = list(range(1,tam+1))
        for i in range(tam-1):
            x_aux1 = x1[-tam:]
            x1 = x1 + x_aux1
        y1 = []
        cont = tam-1
        for i in range(tam):
            for j in range(tam):
                y1 = y1 + [cont]
            cont -= 1
        self.x = x1
        self.y = y1
    def InitPos1(self):
        x2 = list(range(-tam,0))
        for i in range(tam-1):
            x_aux2 = x2[-tam:]
            x2 = x2 + x_aux2
        y2 = []
        cont = tam-1
        for i in range(tam):
            for j in range(tam):
                y2 = y2 + [cont]
            cont -= 1
        self.x = x2
        self.y = y2
    def PosEstrellita(self):
        return self.__estrellita
    def Jugador(self):
        return self.__jugador
    def DistanciaEstrellita(self,pos):
        pos = Pos1Dto2D(pos-1,tam)
        posEstrellita = np.nonzero(self.__tablero)
        return (abs(pos[0]-posEstrellita[0])+abs(pos[1]-posEstrellita[1]))[0]
    def __ActualizarTablero(self):
        self.__tablero = np.zeros((tam,tam))
        indices = Pos1Dto2D(self.__estrellita,tam)
        self.__tablero[indices[0],indices[1]]=1
    def Mover(self,direccion):
        ind = list(Pos1Dto2D(self.__estrellita,tam))
        if direccion == 1:
            ind[0] -= 1
            if ind[0] >= 0:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        elif direccion == 3:
            ind[0] += 1
            if ind[0] < tam:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        elif direccion == 4:
            ind[1] -= 1
            if ind[1] >= 0:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        elif direccion == 2:
            ind[1] += 1
            if ind[1] < tam:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        self.__ActualizarTablero()
        return self.__estrellita
    def Disparo(self,pos):
        if pos-1 == self.__estrellita:
            return 1
        else:
            return 0
    
class Sensor:
    def __init__(self):
        self.__P = [[0.70, 0.15, 0.1, 0.05],
                    [0.17, 0.6, 0.17, 0.06],
                    [0.06, 0.17, 0.6, 0.17],
                    [0.05, 0.12, 0.23, 0.6],
                    [0.03, 0.07, 0.1, 0.8]]
        self.__colors = ["verde", "amarillo", "anaranjado", "rojo"]
        self.colorsG = {"verde":"g", "amarillo":"#fff46f", "anaranjado":"#ff8b00", "rojo":"r"}
    def Sensar(self,dist):
        if dist > 4:
            dist = 4
        probs = self.__P[dist]
        alea = np.random.rand(1)[0]
        cont = 0
        while alea > 0:
            color = self.__colors[cont]
            alea -= probs[cont]
            cont += 1
        return color
    
def Pos2Dto1D(posX,posY,n):
    #pos inicia en 0
    pos1D = posX*n+posY
    return pos1D
def Pos1Dto2D(pos,n):
    indices = np.unravel_index(pos, (n,n))
    return indices
def UnoPorDim(mat,dim):
    maximos = mat.max(axis=dim)
    if np.sum(maximos) == tam:
        return True
    else:
        return False
    
#AGENTE DE PRUEBA
def Agente(a,b,c,d):
    acc = np.random.randint(3)+1
    if acc == 3:
        param = np.random.randint(4)+1
    else:
        param = np.random.randint(25)+1
    return acc, param


#AGENTES DE LOS ESTUDIANTES
    
    
#Ciclo general del juego, debera ser un while mientras nadie haya ganado o 121 iteraciones
jugadorActual = 1 #inicializacion del jugador
tableros = [Tablero("tablero1",1), Tablero("tablero2",2)]
sensor = Sensor()
resultado_accion = [None,None]
accion_oponente = [[None,None,None],[None,None,None]]

agente1 = AgenteAStar()
agente2 = AgenteAStar()


for i in range(turnos*2):

    #ASI VA A SER COMO SE LLAMA AL AGENTE DE CADA UNO
    if jugadorActual == 1:
        print("Agente",jugadorActual,"")
        start = time.time()

         #Para efectos del ejemplo genera una accion aleatoria, esta puede repetir lugar porque esta comentada la parte que lo chequea

        [tipoAccion, parametroAccion] = agente1.get_action_to_take(jugadorActual, resultado_accion[jugadorActual-1], accion_oponente[jugadorActual-1], tableros[jugadorActual-1].PosEstrellita())
        print(tipoAccion, ",", parametroAccion)
        end = time.time()
    else:
        print("Agente",jugadorActual,"")
        start = time.time()

         #Para efectos del ejemplo genera una accion aleatoria, esta puede repetir lugar porque esta comentada la parte que lo chequea

        [tipoAccion, parametroAccion] = agente2.get_action_to_take(jugadorActual, resultado_accion[jugadorActual-1], accion_oponente[jugadorActual-1], tableros[jugadorActual-1].PosEstrellita())
        
        print(tipoAccion, ",", parametroAccion)
        end = time.time()
    
    
    #Actualizacion del estado del tablero
    if tipoAccion == 1:
        puntos = tableros[jugadorActual%2].Disparo(parametroAccion)
        resultado_accion[jugadorActual-1] = puntos
        puntaje[jugadorActual-1] += puntos
        accion_oponente[jugadorActual%2] = [tipoAccion, parametroAccion, puntos]
        
            #Actualizacion del grafico
        pl.cla()
        pl.scatter(tableros[jugadorActual-1].x,tableros[jugadorActual-1].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[jugadorActual%2].x,tableros[jugadorActual%2].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[0].x[tableros[0].PosEstrellita()],tableros[0].y[tableros[0].PosEstrellita()], marker='*', s=size*500, color='#ffd800')
        pl.scatter(tableros[1].x[tableros[1].PosEstrellita()],tableros[1].y[tableros[1].PosEstrellita()], marker='*', s=size*500, color='#c0fcff')
        pl.scatter(tableros[jugadorActual%2].x[parametroAccion-1],tableros[jugadorActual%2].y[parametroAccion-1], marker='X', s=size*450, color=colors[puntos])
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print("Tiempo Agente",jugadorActual," :",end - start)
        
    elif tipoAccion == 2:
        dist = tableros[jugadorActual%2].DistanciaEstrellita(parametroAccion)
        colorSens = sensor.Sensar(dist)
        resultado_accion[jugadorActual-1] = colorSens
        accion_oponente[jugadorActual%2] = [tipoAccion, parametroAccion, colorSens]
        
        #Actualizacion del grafico
        pl.cla()
        pl.scatter(tableros[jugadorActual-1].x,tableros[jugadorActual-1].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[jugadorActual%2].x,tableros[jugadorActual%2].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[0].x[tableros[0].PosEstrellita()],tableros[0].y[tableros[0].PosEstrellita()], marker='*', s=size*500, color='#ffd800')
        pl.scatter(tableros[1].x[tableros[1].PosEstrellita()],tableros[1].y[tableros[1].PosEstrellita()], marker='*', s=size*500, color='#c0fcff')
        pl.scatter(tableros[jugadorActual%2].x[parametroAccion-1],tableros[jugadorActual%2].y[parametroAccion-1], marker='o', s=size*450, color=sensor.colorsG[colorSens])
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print("Tiempo Agente",jugadorActual," :",end - start)
        
    elif tipoAccion == 3:
        tableros[jugadorActual-1].Mover(parametroAccion)
        resultado_accion[jugadorActual-1] = None
        accion_oponente[jugadorActual%2] = [tipoAccion, None, None]
        
        pl.cla()
        pl.scatter(tableros[jugadorActual-1].x,tableros[jugadorActual-1].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[jugadorActual%2].x,tableros[jugadorActual%2].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[0].x[tableros[0].PosEstrellita()],tableros[0].y[tableros[0].PosEstrellita()], marker='*', s=size*500, color='#ffd800')
        pl.scatter(tableros[1].x[tableros[1].PosEstrellita()],tableros[1].y[tableros[1].PosEstrellita()], marker='*', s=size*500, color='#c0fcff')
        
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print("Tiempo Agente",jugadorActual," :",end - start)
    
    print("TURNO: ",i)
    print(accion_oponente)
    time.sleep(1)


    #ACA SE CHEQUEARIA SI ALGUIEN GANO
    if jugadorActual == 1:
        if puntaje[0] >= ganar:
            print("GANO JUGADOR 1")
    else:
        if puntaje[1] >= ganar:
            print("GANO JUGADOR 2")

    #Cambio de jugados
    if (i+1)%2 == 0:
        jugadorActual = 1
    else:
        jugadorActual = 2
print("PUNTAJE FINAL: ", puntaje)
# Out:
# Agente 1
# 2 , 5
# Tiempo Agente 1  : 0.00024199485778808594
# TURNO:  0
# [[None, None, None], [2, 5, 'anaranjado']]
# Agente 2
# 2 , 9
# Tiempo Agente 2  : 0.00067901611328125
# TURNO:  1
# [[2, 9, 'rojo'], [2, 5, 'anaranjado']]
# Agente 1
# Risk level: 2.6
# 1 , 9
# Tiempo Agente 1  : 0.0013587474822998047
# TURNO:  2
# [[2, 9, 'rojo'], [1, 9, 0]]
# Agente 2
# Risk level: 4
# 3 , 15
# Tiempo Agente 2  : 0.0012021064758300781
# TURNO:  3
# [[3, None, None], [1, 9, 0]]
# Agente 1
# Risk level: 0
# 2 , 7
# Tiempo Agente 1  : 0.0018851757049560547
# TURNO:  4
# [[3, None, None], [2, 7, 'verde']]
# Agente 2
# Risk level: 2.12
# 2 , 17
# Tiempo Agente 2  : 0.00038886070251464844
# TURNO:  5
# [[2, 17, 'rojo'], [2, 7, 'verde']]
# Agente 1
# Risk level: 2.6
# 1 , 7
# Tiempo Agente 1  : 0.0018968582153320312
# TURNO:  6
# [[2, 17, 'rojo'], [1, 7, 0]]
# Agente 2
# Risk level: 3
# 2 , 1
# Tiempo Agente 2  : 0.001024007797241211
# TURNO:  7
# [[2, 1, 'anaranjado'], [1, 7, 0]]
# Agente 1
# Risk level: 0.2
# 1 , 3
# Tiempo Agente 1  : 0.0012979507446289062
# TURNO:  8
# [[2, 1, 'anaranjado'], [1, 3, 0]]
# Agente 2
# Risk level: 3
# 1 , 7
# Tiempo Agente 2  : 0.0016090869903564453
# TURNO:  9
# [[1, 7, 0], [1, 3, 0]]
# Agente 1
# Risk level: 2
# 1 , 7
# Tiempo Agente 1  : 0.0016057491302490234
# TURNO:  10
# [[1, 7, 0], [1, 7, 0]]
# Agente 2
# Risk level: 3
# 2 , 3
# Tiempo Agente 2  : 0.0012290477752685547
# TURNO:  11
# [[2, 3, 'rojo'], [1, 7, 0]]
# Agente 1
# Risk level: 1.8
# 1 , 9
# Tiempo Agente 1  : 0.0015149116516113281
# TURNO:  12
# [[2, 3, 'rojo'], [1, 9, 0]]
# Agente 2
# Risk level: 3
# 2 , 6
# Tiempo Agente 2  : 0.0014472007751464844
# TURNO:  13
# [[2, 6, 'rojo'], [1, 9, 0]]
# Agente 1
# Risk level: 1.8
# 2 , 7
# Tiempo Agente 1  : 0.001615762710571289
# TURNO:  14
# [[2, 6, 'rojo'], [2, 7, 'anaranjado']]
# Agente 2
# Risk level: 2.2
# 2 , 17
# Tiempo Agente 2  : 0.0014159679412841797
# TURNO:  15
# [[2, 17, 'rojo'], [2, 7, 'anaranjado']]
# Agente 1
# Risk level: 2.6
# 1 , 3
# Tiempo Agente 1  : 0.0013511180877685547
# TURNO:  16
# [[2, 17, 'rojo'], [1, 3, 0]]
# Agente 2
# Risk level: 3
# 2 , 14
# Tiempo Agente 2  : 0.001438140869140625
# TURNO:  17
# [[2, 14, 'amarillo'], [1, 3, 0]]
# Agente 1
# Risk level: 3.51
# 2 , 6
# Tiempo Agente 1  : 0.0015020370483398438
# TURNO:  18
# [[2, 14, 'amarillo'], [2, 6, 'rojo']]
# Agente 2
# Risk level: 1.8
# 1 , 9
# Tiempo Agente 2  : 0.0016028881072998047
# TURNO:  19
# [[1, 9, 0], [2, 6, 'rojo']]
# Agente 1
# Risk level: 3
# 2 , 13
# Tiempo Agente 1  : 0.0015790462493896484
# TURNO:  20
# [[1, 9, 0], [2, 13, 'rojo']]
# Agente 2
# Risk level: 3.17
# 1 , 14
# Tiempo Agente 2  : 0.0015571117401123047
# TURNO:  21
# [[1, 14, 0], [2, 13, 'rojo']]
# Agente 1
# Risk level: 3
# 1 , 5
# Tiempo Agente 1  : 0.0013799667358398438
# TURNO:  22
# [[1, 14, 0], [1, 5, 0]]
# Agente 2
# Risk level: 3
# 2 , 10
# Tiempo Agente 2  : 0.0010180473327636719
# TURNO:  23
# [[2, 10, 'rojo'], [1, 5, 0]]
# Agente 1
# Risk level: 2.8
# 1 , 9
# Tiempo Agente 1  : 0.000997304916381836
# TURNO:  24
# [[2, 10, 'rojo'], [1, 9, 0]]
# Agente 2
# Risk level: 3
# 2 , 19
# Tiempo Agente 2  : 0.0013370513916015625
# TURNO:  25
# [[2, 19, 'anaranjado'], [1, 9, 0]]
# Agente 1
# Risk level: 3.34
# 2 , 5
# Tiempo Agente 1  : 0.0009748935699462891
# TURNO:  26
# [[2, 19, 'anaranjado'], [2, 5, 'amarillo']]
# Agente 2
# Risk level: 3.51
# 1 , 23
# Tiempo Agente 2  : 0.0014851093292236328
# TURNO:  27
# [[1, 23, 0], [2, 5, 'amarillo']]
# Agente 1
# Risk level: 4
# 3 , 19
# Tiempo Agente 1  : 0.000946044921875
# TURNO:  28
# [[1, 23, 0], [3, None, None]]
# Agente 2
# Risk level: 0
# 1 , 19
# Tiempo Agente 2  : 0.0012040138244628906
# TURNO:  29
# [[1, 19, 0], [3, None, None]]
# Agente 1
# Risk level: 5
# 3 , 14
# Tiempo Agente 1  : 0.0007679462432861328
# TURNO:  30
# [[1, 19, 0], [3, None, None]]
# Agente 2
# Risk level: 0
# 2 , 17
# Tiempo Agente 2  : 0.0015070438385009766
# TURNO:  31
# [[2, 17, 'rojo'], [3, None, None]]
# Agente 1
# Risk level: 2.6
# 1 , 10
# Tiempo Agente 1  : 0.0011560916900634766
# TURNO:  32
# [[2, 17, 'rojo'], [1, 10, 1]]
# Agente 2
# Risk level: 4
# 3 , 14
# Tiempo Agente 2  : 0.0013358592987060547
# TURNO:  33
# [[3, None, None], [1, 10, 1]]
# Agente 1
# Risk level: 0
# 1 , 15
# Tiempo Agente 1  : 0.011266231536865234
# TURNO:  34
# [[3, None, None], [1, 15, 0]]
# Agente 2
# Risk level: 4
# 3 , 9
# Tiempo Agente 2  : 0.0010721683502197266
# TURNO:  35
# [[3, None, None], [1, 15, 0]]
# Agente 1
# Risk level: 0
# 1 , 4
# Tiempo Agente 1  : 0.009793996810913086
# TURNO:  36
# [[3, None, None], [1, 4, 0]]
# Agente 2
# Risk level: 4
# 3 , 14
# Tiempo Agente 2  : 0.0012149810791015625
# TURNO:  37
# [[3, None, None], [1, 4, 0]]
# Agente 1
# Risk level: 0
# 1 , 9
# Tiempo Agente 1  : 0.011096000671386719
# TURNO:  38
# [[3, None, None], [1, 9, 0]]
# Agente 2
# Risk level: 4
# 3 , 19
# Tiempo Agente 2  : 0.0009598731994628906
# TURNO:  39
# [[3, None, None], [1, 9, 0]]
# Agente 1
# Risk level: 0
# 1 , 10
# Tiempo Agente 1  : 0.012358903884887695
# TURNO:  40
# [[3, None, None], [1, 10, 1]]
# Agente 2
# Risk level: 3
# 1 , 24
# Tiempo Agente 2  : 0.0011210441589355469
# TURNO:  41
# [[1, 24, 1], [1, 10, 1]]
# Agente 1
# 1 , 10
# Tiempo Agente 1  : 0.0007188320159912109
# TURNO:  42
# [[1, 24, 1], [1, 10, 1]]
# Agente 2
# 1 , 24
# Tiempo Agente
#  2  : 0.0007169246673583984
# TURNO:  43
# [[1, 24, 1], [1, 10, 1]]
# Agente 1
# 1 , 10
# Tiempo Agente
#  1  : 0.000637054443359375
# TURNO:  44
# [[1, 24, 1], [1, 10, 1]]
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.0002200603485107422
# TURNO:  45
# [[1, 24, 1], [1, 10, 1]]
# Agente 1
# 1 , 10
# Tiempo Agente 1  : 0.0009150505065917969
# TURNO:  46
# [[1, 24, 1], [1, 10, 1]]
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.00027298927307128906
# TURNO:  47
# [[1, 24, 1], [1, 10, 1]]
# Agente 1
# 1 , 10
# Tiempo Agente 1  : 0.0005578994750976562
# TURNO:  48
# [[1, 24, 1], [1, 10, 1]]
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.00041222572326660156
# TURNO:  49
# [[1, 24, 1], [1, 10, 1]]
# Agente 1
# 1 , 10
# Tiempo Agente 1  : 0.0006270408630371094
# TURNO:  50
# [[1, 24, 1], [1, 10, 1]]
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.00075531005859375
# TURNO:  51
# [[1, 24, 1], [1, 10, 1]]
# Agente 1
# 1 , 10
# Tiempo Agente 1  : 0.0007128715515136719
# TURNO:  52
# [[1, 24, 1], [1, 10, 1]]
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.0006990432739257812
# TURNO:  53
# [[1, 24, 1], [1, 10, 1]]
# Agente 1
# 1 , 10
# Tiempo Agente 1  : 0.0007450580596923828
# TURNO:  54
# [[1, 24, 1], [1, 10, 1]]
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.0007512569427490234
# TURNO:  55
# [[1, 24, 1], [1, 10, 1]]
# Agente 1
# 1 , 10
# Tiempo Agente 1  : 0.0006222724914550781
# TURNO:  56
# [[1, 24, 1], [1, 10, 1]]
# GANO JUGADOR 1
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.00055694580078125
# TURNO:  57
# [[1, 24, 1], [1, 10, 1]]
# Agente 1
# 1 , 10
# Tiempo Agente 1  : 0.0006949901580810547
# TURNO:  58
# [[1, 24, 1], [1, 10, 1]]
# GANO JUGADOR 1
# Agente 2
# 1 , 24
# Tiempo Agente 2  : 0.0004000663757324219
# TURNO:  59
# [[1, 24, 1], [1, 10, 1]]
# GANO JUGADOR 2
# PUNTAJE FINAL:  [11, 10]
