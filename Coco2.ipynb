# %%
# %matplotlib inline
import time
import random
import pylab as pl
from IPython import display
from itertools import compress
import numpy as np
from Agente_A_Star import AgenteAStar


#Tamaño del tamblero
tam = 5
#Colores de los jugadores
ganar = 10
puntaje = [0,0]
turnos = 30
colors = ["#ffc0f7","red"]

#Parametros de la grafica
xmax = tam + tam/2
xmin = -tam - tam/2
ymax = tam-1 + 0.5
ymin = -0.5
pl.xlim(xmin, xmax)
pl.ylim(ymin, ymax)

#Tamaño de los cuadrados
size = (1)**(2)

class Tablero:
    def __init__(self,name,jugador):
        self.__name = name
        self.__estrellita = np.random.randint(tam**2)
        self.__tablero = np.zeros((tam,tam))
        self.__jugador = jugador
        indices = Pos1Dto2D(self.__estrellita-1,tam)
        self.__tablero[indices[0],indices[1]]=1
        if jugador == 1:
            self.InitPos1()
        else:
            self.InitPos2()
    def InitPos2(self):
        x1 = list(range(1,tam+1))
        for i in range(tam-1):
            x_aux1 = x1[-tam:]
            x1 = x1 + x_aux1
        y1 = []
        cont = tam-1
        for i in range(tam):
            for j in range(tam):
                y1 = y1 + [cont]
            cont -= 1
        self.x = x1
        self.y = y1
    def InitPos1(self):
        x2 = list(range(-tam,0))
        for i in range(tam-1):
            x_aux2 = x2[-tam:]
            x2 = x2 + x_aux2
        y2 = []
        cont = tam-1
        for i in range(tam):
            for j in range(tam):
                y2 = y2 + [cont]
            cont -= 1
        self.x = x2
        self.y = y2
    def PosEstrellita(self):
        return self.__estrellita
    def Jugador(self):
        return self.__jugador
    def DistanciaEstrellita(self,pos):
        pos = Pos1Dto2D(pos-1,tam)
        posEstrellita = np.nonzero(self.__tablero)
        return (abs(pos[0]-posEstrellita[0])+abs(pos[1]-posEstrellita[1]))[0]
    def __ActualizarTablero(self):
        self.__tablero = np.zeros((tam,tam))
        indices = Pos1Dto2D(self.__estrellita,tam)
        self.__tablero[indices[0],indices[1]]=1
    def Mover(self,direccion):
        ind = list(Pos1Dto2D(self.__estrellita,tam))
        if direccion == 1:
            ind[0] -= 1
            if ind[0] >= 0:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        elif direccion == 3:
            ind[0] += 1
            if ind[0] < tam:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        elif direccion == 4:
            ind[1] -= 1
            if ind[1] >= 0:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        elif direccion == 2:
            ind[1] += 1
            if ind[1] < tam:
                self.__estrellita = Pos2Dto1D(ind[0],ind[1],tam)
        self.__ActualizarTablero()
        return self.__estrellita
    def Disparo(self,pos):
        if pos-1 == self.__estrellita:
            return 1
        else:
            return 0
    
class Sensor:
    def __init__(self):
        self.__P = [[0.70, 0.15, 0.1, 0.05],
                    [0.17, 0.6, 0.17, 0.06],
                    [0.06, 0.17, 0.6, 0.17],
                    [0.05, 0.12, 0.23, 0.6],
                    [0.05, 0.1, 0.15, 0.8]]
        self.__colors = ["verde", "amarillo", "anaranjado", "rojo"]
        self.colorsG = {"verde":"g", "amarillo":"#fff46f", "anaranjado":"#ff8b00", "rojo":"r"}
    def Sensar(self,dist):
        if dist > 4:
            dist = 4
        probs = self.__P[dist]
        alea = np.random.rand(1)[0]
        cont = 0
        while alea > 0:
            color = self.__colors[cont]
            alea -= probs[cont]
            cont += 1
        return color
    
def Pos2Dto1D(posX,posY,n):
    #pos inicia en 0
    pos1D = posX*n+posY
    return pos1D
def Pos1Dto2D(pos,n):
    indices = np.unravel_index(pos, (n,n))
    return indices
def UnoPorDim(mat,dim):
    maximos = mat.max(axis=dim)
    if np.sum(maximos) == tam:
        return True
    else:
        return False
    
#AGENTE DE PRUEBA
def Agente(a,b,c,d):
    acc = np.random.randint(3)+1
    if acc == 3:
        param = np.random.randint(4)+1
    else:
        param = np.random.randint(25)+1
    return acc, param


#AGENTES DE LOS ESTUDIANTES
    
    
#Ciclo general del juego, debera ser un while mientras nadie haya ganado o 121 iteraciones
jugadorActual = 1 #inicializacion del jugador
tableros = [Tablero("tablero_1",1), Tablero("tablero_2",2)]
sensor = Sensor()
resultado_accion = [None,None]
accion_oponente = [[None,None,None],[None,None,None]]

agente = AgenteAStar()
agente2 = AgenteAStar()

for i in range(turnos*2):

    #ASI VA A SER COMO SE LLAMA AL AGENTE DE CADA UNO
    if jugadorActual == 1:
        print("Agente",jugadorActual,"")
        start = time.time()

         #Para efectos del ejemplo genera una accion aleatoria, esta puede repetir lugar porque esta comentada la parte que lo chequea

        [tipoAccion, parametroAccion] = agente.get_action_to_take(jugadorActual, resultado_accion[jugadorActual-1], accion_oponente[(jugadorActual%2)-1], tableros[jugadorActual-1].PosEstrellita())
        
        print(tipoAccion)
        end = time.time()
        
    else:
        print("Agente",jugadorActual,"")
        start = time.time()

         #Para efectos del ejemplo genera una accion aleatoria, esta puede repetir lugar porque esta comentada la parte que lo chequea

        [tipoAccion, parametroAccion] = agente2.get_action_to_take(jugadorActual, resultado_accion[jugadorActual-1], accion_oponente[(jugadorActual%2)+1], tableros[jugadorActual-1].PosEstrellita())
        
        print(tipoAccion)
        end = time.time()
    
    
    #Actualizacion del estado del tablero
    if tipoAccion == 1:
        puntos = tableros[jugadorActual%2].Disparo(parametroAccion)
        resultado_accion[jugadorActual-1] = puntos
        puntaje[jugadorActual-1] += puntos
        accion_oponente[jugadorActual%2] = [tipoAccion, parametroAccion, puntos]
        
            #Actualizacion del grafico
        pl.cla()
        pl.scatter(tableros[jugadorActual-1].x,tableros[jugadorActual-1].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[jugadorActual%2].x,tableros[jugadorActual%2].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[0].x[tableros[0].PosEstrellita()],tableros[0].y[tableros[0].PosEstrellita()], marker='*', s=size*500, color='#ffd800')
        pl.scatter(tableros[1].x[tableros[1].PosEstrellita()],tableros[1].y[tableros[1].PosEstrellita()], marker='*', s=size*500, color='#c0fcff')
        pl.scatter(tableros[jugadorActual%2].x[parametroAccion-1],tableros[jugadorActual%2].y[parametroAccion-1], marker='X', s=size*450, color=colors[puntos])
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print("Tiempo Agente",jugadorActual," :",end - start)
        
    elif tipoAccion == 2:
        dist = tableros[jugadorActual%2].DistanciaEstrellita(parametroAccion)
        colorSens = sensor.Sensar(dist)
        resultado_accion[jugadorActual-1] = colorSens
        accion_oponente[jugadorActual%2] = [tipoAccion, parametroAccion, colorSens]
        
        #Actualizacion del grafico
        pl.cla()
        pl.scatter(tableros[jugadorActual-1].x,tableros[jugadorActual-1].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[jugadorActual%2].x,tableros[jugadorActual%2].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[0].x[tableros[0].PosEstrellita()],tableros[0].y[tableros[0].PosEstrellita()], marker='*', s=size*500, color='#ffd800')
        pl.scatter(tableros[1].x[tableros[1].PosEstrellita()],tableros[1].y[tableros[1].PosEstrellita()], marker='*', s=size*500, color='#c0fcff')
        pl.scatter(tableros[jugadorActual%2].x[parametroAccion-1],tableros[jugadorActual%2].y[parametroAccion-1], marker='o', s=size*450, color=sensor.colorsG[colorSens])
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print("Tiempo Agente",jugadorActual," :",end - start)
        
    elif tipoAccion == 3:
        tableros[jugadorActual-1].Mover(parametroAccion)
        resultado_accion[jugadorActual-1] = None
        accion_oponente[jugadorActual%2] = [tipoAccion, parametroAccion, None]
        
        pl.cla()
        pl.scatter(tableros[jugadorActual-1].x,tableros[jugadorActual-1].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[jugadorActual%2].x,tableros[jugadorActual%2].y, marker='s', s=size*100, color='grey')
        pl.scatter(tableros[0].x[tableros[0].PosEstrellita()],tableros[0].y[tableros[0].PosEstrellita()], marker='*', s=size*500, color='#ffd800')
        pl.scatter(tableros[1].x[tableros[1].PosEstrellita()],tableros[1].y[tableros[1].PosEstrellita()], marker='*', s=size*500, color='#c0fcff')
        
        display.clear_output(wait=True)
        display.display(pl.gcf())
        print("Tiempo Agente",jugadorActual," :",end - start)
    
    print("TURNO: ",i)
    print(accion_oponente)
    time.sleep(1)


    #ACA SE CHEQUEARIA SI ALGUIEN GANO
    if jugadorActual == 1:
        if puntaje[0] >= ganar:
            print("GANO JUGADOR 1")
    else:
        if puntaje[1] >= ganar:
            print("GANO JUGADOR 2")

    #Cambio de jugados
    if (i+1)%2 == 0:
        jugadorActual = 1
    else:
        jugadorActual = 2
print("PUNTAJE FINAL: ", puntaje)
# Out:
# Agente 1
# Before executing:
# Action result: None Adversary action: [None, None, None]
# First turn = Random observation.
# Action to take: [2, 8]
# 2
# Tiempo Agente 1  : 0.0047740936279296875
# TURNO:  0
# [[None, None, None], [2, 8, 'rojo']]
# Agente 2
# Before executing:
# Action result: None Adversary action: [2, 8, 'rojo']
# First turn for second player = Random observation.
# Action to take: [2, 6]
# 2
# Tiempo Agente 2  : 0.0008511543273925781
# TURNO:  1
# [[2, 6, 'amarillo'], [2, 8, 'rojo']]
# Agente 1
# Before executing:
# Action result: rojo Adversary action: [2, 6, 'amarillo']
# Agent previous action = [2, 8] Result for that action = rojo
# Previous action was OBSERVE.
# -----------
# UPDATED BELIEF AFTER ELAPSING TIME:
# -----------
# [0.026666666666666665, 0.043333333333333335, 0.03666666666666667, 0.043333333333333335, 0.026666666666666665]
# [0.043333333333333335, 0.04666666666666667, 0.043333333333333335, 0.04666666666666667, 0.043333333333333335]
# [0.03666666666666667, 0.043333333333333335, 0.04, 0.043333333333333335, 0.03666666666666667]
# [0.043333333333333335, 0.04666666666666666, 0.043333333333333335, 0.04666666666666666, 0.043333333333333335]
# [0.026666666666666665, 0.043333333333333335, 0.03666666666666667, 0.043333333333333335, 0.026666666666666665]
# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# [0

# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# [0.04753087215159041, 0.13682942506444337, 0.05130554341912373, 0.01873375056191987, 0.0022299428331436764]
# [0.0208423575410807, 0.06370856708692069, 0.13602751246882552, 0.02721660701557844, 0.007547053166279168]
# [0.044708952998444566, 0.13268197645567012, 0.03674244767539395, 0.013886895306397933, 0.004476323585882802]
# [0.10435723615380328, 0.04935746465701941, 0.016407379222067864, 0.010104619062879275, 0.0024469539552357377]
# [0.036412378319716936, 0.0182594795617689, 0.014909669921842275, 0.0028600019197047213, 0.00041658989526672575]
# Adversary action: 2 Adversary action param: 2 Adversary action result: rojo
# Risk level: 1.8
# The agent has to SHOOT.
# Action to take: [1, 2]
# 1
# Tiempo Agente 2  : 0.007582902908325195
# TURNO:  31
# [[1, 2, 0], [2, 2, 'rojo']]
# Agente 1
# Before executing:
# Action result: rojo Adversary action: [1, 2, 0]
# Agent previous action = [2, 2] Result for that action = rojo
# Previous action was OBSERVE.
# -----------
# UPDATED BELIEF AFTER ELAPSING TIME:
# -----------
# [0.04558420585657256, 0.0751768704615832, 0.07327233553120942, 0.03288165590403037, 0.006739885391007023]
# [0.07309798659082739, 0.1015920952477437, 0.06592896302614472, 0.03798123701933909, 0.013452534297348865]
# [0.06037334703382707, 0.06801070640563814, 0.06187628377499801, 0.028601262282048033, 0.0048106779910975506]
# [0.05222418251976675, 0.06228711863310291, 0.035362765383268914, 0.006971602321587055, 0.006221892264118626]
# [0.03165218648643697, 0.0374748206348127, 0.00849940889064071, 0.008822768115090265, 0.0011032079377601778]
# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# ...
# [0.0944648463653379, 0.0373275332366111, 0.014035298773893751, 0.006989678926797137, 0.0012185622294903359]
# [0.027764024301572404, 0.014522595874698433, 0.008286095668215579, 0.00124635579884513, 0.0004771756037537905]
# Adversary action: 2 Adversary action param: 24 Adversary action result: anaranjado
# Risk level: 4.2
# The agent is at risk and it has to MOVE.
# Action to take: [3, 19]
# 3
# Tiempo Agente 2  : 0.007143974304199219
# TURNO:  47
# [[3, 19, None], [2, 24, 'anaranjado']]
# Agente 1
# Before executing:
# Action result: anaranjado Adversary action: [3, 19, None]
# Agent previous action = [2, 24] Result for that action = anaranjado
# Previous action was OBSERVE.
# -----------
# UPDATED BELIEF AFTER ELAPSING TIME:
# -----------
# [0.0007008606212034323, 0.0034381332460518216, 0.01212681603957433, 0.013029820438123892, 0.005643478990797824]
# [0.004892266081081966, 0.0207923618185293, 0.026781579011401824, 0.03868282090027057, 0.037844291381123295]
# [0.019110100234578556, 0.033191707474416826, 0.047940775187816, 0.07200596013197462, 0.05917253766807089]
# [0.036308705280209394, 0.043875469597974885, 0.07016566144696842, 0.09780478801337146, 0.07434032506582236]
# [0.02897403631963164, 0.052872749075187596, 0.06280521120010646, 0.0675440307528313, 0.06995551402288133]
# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# [0.00036257803695478327, 0.00177865836006302, 0.006273597090660894, 0.0067407506905099585, 0.0029195555752091606]
# [0.002530928658673059, 0.010756566289701284, 0.01385498350275403, 0.030684888393514843, 0.019578085091086453]
# [0.00988627755567886, 0.017171151831283003, 0.03802869857731678, 0.14900411798777707, 0.04693821887982083]
# [0.018783676363872764, 0.0348039221673592, 0.14519593208357096, 0.057343950992728016, 0.1538346901708584]
# [0.022983460101569885, 0.10941118383947503, 0.036823339902893666, 0.02329515202449609, 0.04101563583217179]
# Adversary action: 3 Adversary action param: 19 Adversary action result: None
# Risk level: 0
# The agent has to SHOOT.
# Action to take: [1, 20]
# 1
# Tiempo Agente 1  : 0.007543087005615234
# TURNO:  48
# [[3, 19, None], [1, 20, 0]]
# Agente 2
# Before executing:
# Action result: None Adversary action: [1, 20, 0]
# Agent previous action = [3, 19] Result for that action = None
# Adversary action: 1 Adversary action param: 20 Adversary action result: 0
# Risk level: 3
# The agent has to SHOOT.
# Action to take: [1, 2]
# 1
# Tiempo Agente 2  : 0.0037560462951660156
# TURNO:  49
# [[1, 2, 0], [1, 20, 0]]
# Agente 1
# Before executing:
# Action result: 0 Adversary action: [1, 2, 0]
# Agent previous action = [1, 20] Result for that action = 0
# Previous action was SHOOT.
# -----------
# UPDATED BELIEF AFTER ELAPSING TIME:
# -----------
# [0.0014365290062453595, 0.004961629621123011, 0.006303548892546166, 0.011222198916203588, 0.008772945260532137]
# [0.0061658564427956655, 0.009193062839754618, 0.021958737345353523, 0.04948772063316491, 0.024777072845923568]
# [0.01139765629866936, 0.024192722610487268, 0.08130654635134626, 0.04716045745083019, 0.09505528791759255]
# [0.023488136444517693, 0.08332339104649608, 0.044818589568648884, 0.13259329324962182, 0.05048987862420817]
# [0.0427316200677826, 0.03246715722692263, 0.08053442830888312, 0.04711825229856578, 0.05904328073178483]
# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# [0.0008577084113713788, 0.002962440327793653, 0.003763660102317584, 0.006700438600727128, 0.008031696073157197]
# [0.003681448067739868, 0.0054889022704331224, 0.013110903881733143, 0.04530637313640115, 0.05917459013140252]
# [0.006805198944669945, 0.01444474952247871, 0.07443674269688433, 0.11263238225985452, 0.06432195167854828]
# [0.014024062241915162, 0.07628317888645884, 0.10703934578893119, 0.08972314521518898, 0.020097328768084167]
# [0.0255137695127077, 0.01938516641556227, 0.07372986293581205, 0.11253158453438428, 0.03995336959544301]
# Adversary action: 1 Adversary action param: 2 Adversary action result: 0
# Risk level: 3
# The agent has to OBSERVE.
# Action to take: [2, 14]
# 2
# Tiempo Agente 1  : 0.007230043411254883
# TURNO:  50
# [[1, 2, 0], [2, 14, 'amarillo']]
# Agente 2
# Before executing:
# Action result: 0 Adversary action: [2, 14, 'amarillo']
# Agent previous action = [1, 2] Result for that action = 0
# Previous action was SHOOT.
# -----------
# UPDATED BELIEF AFTER ELAPSING TIME:
# -----------
# [0.06037012160850691, 0.06795326692245417, 0.09293076055775883, 0.024054120124395235, 0.007580935387856835]
# [0.06823799030960653, 0.12931870807595225, 0.04967044283878652, 0.04519810162498318, 0.007612922025940531]
# [0.07370852186560273, 0.053742068888967154, 0.07531803004544006, 0.015851353774065966, 0.0050154494565782266]
# [0.04118992104415942, 0.07403001122165917, 0.02115018422788606, 0.007191082920773202, 0.0032361116321895527]
# [0.03632914741334545, 0.02597592734934417, 0.008765141917987959, 0.004748039422981372, 0.0008216393427784886]
# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# [0.03911343124571994, 0.02589794385306281, 0.06020926936771596, 0.05500417689651096, 0.006645162038797267]
# [0.15603873559463088, 0.08378479721997671, 0.11358061780284466, 0.039618951195012, 0.004352087164783642]
# [0.06461011028028715, 0.12289114083849897, 0.06602094444659871, 0.009061760132244932, 0.00286718728120672]
# [0.023547085611006376, 0.06489191572452899, 0.01209094812705906, 0.00411093395857098, 0.0018499913502685872]
# [0.020768322022268484, 0.014849685787562829, 0.005010777925847687, 0.002714316705232648, 0.0004697074297625888]
# Adversary action: 2 Adversary action param: 14 Adversary action result: amarillo
# Risk level: 3.51
# The agent has to SHOOT.
# Action to take: [1, 6]
# 1
# Tiempo Agente 2
#  : 0.00692296028137207
# TURNO:  51
# [[1, 6, 0], [2, 14, 'amarillo']]
# Agente 1
# Before executing:
# Action result: amarillo Adversary action: [1, 6, 0]
# Agent previous action = [2, 14] Result for that action = amarillo
# Previous action was OBSERVE.
# -----------
# UPDATED BELIEF AFTER ELAPSING TIME:
# -----------
# [0

# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# [0.0005126662479014138, 0.00138964934645794, 0.00523722825718926, 0.031729570728448946, 0.006529368676314146]
# [0.0016499146457276258, 0.007290620975636114, 0.05895802111549662, 0.06196408062306659, 0.0670002678148549]
# [0.0065367929402842025, 0.03696998045432293, 0.08208590771995616, 0.10535458253812792, 0.07313381291936208]
# [0.00722383643674231, 0.07228604261023543, 0.06902348278136046, 0.0198311426007416, 0.06957014514299417]
# [0.006511685202022318, 0.015328733336930656, 0.08008365731108395, 0.04978604277931, 0.0640127667954322]
# Adversary action: 3 Adversary action param: 23 Adversary action result: None
# Risk level: 0
# The agent has to OBSERVE.
# Action to take: [2, 14]
# 2
# Tiempo Agente 1  : 0.006505250930786133
# TURNO:  54
# [[3, 23, None], [2, 14, 'amarillo']]
# Agente 2
# Before executing:
# Action result: None Adversary action: [2, 14, 'amarillo']
# Agent previous action = [3, 23] Result for that action = None
# Adversary action: 2 Adversary action param: 14 Adversary action result: amarillo
# Risk level: 3.51
# The agent has to SHOOT.
# Action to take: [1, 12]
# 1
# Tiempo Agente 2  : 0.003916025161743164
# TURNO:  55
# [[1, 12, 0], [2, 14, 'amarillo']]
# Agente 1
# Before executing:
# Action result: amarillo Adversary action: [1, 12, 0]
# Agent previous action = [2, 14] Result for that action = amarillo
# Previous action was OBSERVE.
# -----------
# UPDATED BELIEF AFTER ELAPSING TIME:
# -----------
# [0.0010131879973951886, 0.0038247311202561553, 0.025779245303843117, 0.02050144724632014, 0.032909946181101275]
# [0.00425791934795447, 0.024995188389850077, 0.03958089508206114, 0.0739880970945074, 0.04313364213371108]
# [0.012200412141070711, 0.042594573806551655, 0.06757651672232698, 0.06534822037572845, 0.07186211662048167]
# [0.02350628423366475, 0.034015889066811834, 0.07024532566976127, 0.08337991230397349, 0.06134210668768886]
# [0.007517523257890988, 0.048021905690598, 0.03896079606742033, 0.06365872148492949, 0.03978539597410139]
# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# [0.0003622181277101357, 0.001367354280681941, 0.01105940061478589, 0.012459872161141815, 0.014118500163136389]
# [0.001522220533723186, 0.010723037024058543, 0.024055516023853855, 0.15870596614631077, 0.02621471842320531]
# [0.005234026207644011, 0.02588709655525486, 0.14495299644644324, 0.035043313917861016, 0.15414569498935066]
# [0.008403575927103418, 0.01459295413903777, 0.04269199960603268, 0.17885159990659008, 0.03728101720042787]
# [0.002687539929895743, 0.01716799331717362, 0.016714339264087802, 0.03868895313165383, 0.017068095962835744]
# Adversary action: 1 Adversary action param: 12 Adversary action result: 0
# Risk level: 3
# The agent has to SHOOT.
# Action to take: [1, 19]
# 1
# Tiempo Agente 1  : 0.007113933563232422
# TURNO:  56
# [[1, 12, 0], [1, 19, 0]]
# Agente 2
# Before executing:
# Action result: 0 Adversary action: [1, 19, 0]
# Agent previous action = [1, 12] Result for that action = 0
# Previous action was SHOOT.
# -----------
# UPDATED BELIEF AFTER ELAPSING TIME:
# -----------
# [0.04997512099020891, 0.05105605571834283, 0.08419302793386294, 0.030406156391943655, 0.008365313923922951]
# [0.054187486820676915, 0.12536690173979095, 0.05616235496295301, 0.04775563321292453, 0.016213277056984585]
# [0.08096934639054315, 0.05850327559378726, 0.08382485742805523, 0.02493377917961302, 0.006641570123999001]
# [0.03270468548306048, 0.08334561609887399, 0.024943962658788895, 0.009340637381756105, 0.0020652763714021543]
# [0.038911077959820344, 0.01618106899644303, 0.010179986556885248, 0.0028659703220778624, 0.000907560703282911]
# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# [0.03944759376439657, 0.10513258381457655, 0.06645731511846079, 0.01565278467156773, 0.004306379796031272]
# [0.11158070124538376, 0.07314264162789981, 0.11564727057921473, 0.037695652989295475, 0.008346432588260016]
# [0.0472398360627992, 0.020077933421263072, 0.04890582299860753, 0.05134263884143012, 0.005242487762272656]
# [0.0673441776749303, 0.048626219879226495, 0.05136360825363635, 0.007372982028562596, 0.0010631835840126127]
# [0.030714250728767295, 0.033319408805541954, 0.008035517798980495, 0.0014753728076750442, 0.00046720315720759527]
# Adversary action: 1 Adversary action param: 19 Adversary action result: 0
# Risk level: 4
# The agent is at risk and it has to MOVE.
# Action to take: [3, 23]
# 3
# Tiempo Agente 2  : 0.0068433284759521484
# TURNO:  57
# [[3, 23, None], [1, 19, 0]]
# Agente 1
# Before executing:
# Action result: 0 Adversary action: [3, 23, None]
# Agent previous action = [1, 19] Result for that action = 0
# Previous action was SHOOT.
# -----------
# UPDATED BELIEF AFTER ELAPSING TIME:
# -----------
# [0.0009631916048017089, 0.006548335191465, 0.01062295448657138, 0.05042220848974119, 0.012891530194782374]
# [0.004606543722417707, 0.013448844749578888, 0.08228196677579844, 0.027666237680211092, 0.09811763994792944]
# [0.00978037295908925, 0.044311922304932895, 0.0319194815257506, 0.17200953895461957, 0.02992607368734298]
# [0.006736683902255318, 0.025668630455080898, 0.09017083404438038, 0.04475715182500065, 0.10462884628784894]
# [0.008523856414759012, 0.010563454921069915, 0.02929198205111732, 0.05881839437942799, 0.025323323444027233]
# -----------
# UPDATED BELIEF AFTER OBSERVATION:
# -----------
# [0.0005641993163865373, 0.0038357541947794008, 0.006222504047429628, 0.04528749590647056, 0.007551345429936533]
# [0.0026983300167237436, 0.007877798120409467, 0.07390283657038692, 0.06482312473799444, 0.08812589433480435]
# [0.005728953315222811, 0.03979944671405627, 0.07478864876505512, 0.11419052275151848, 0.07011801279147567]
# [0.006050658108492935, 0.06014264942982651, 0.05986095154399972, 0.017477972425000123, 0.06945907026499168]
# [0.004992935920754926, 0.009487732406514342, 0.06863231019231902, 0.039047271694413646, 0.059333581001037354]
# Adversary action: 3 Adversary action param: 23 Adversary action result: None
# Risk level: 0
# The agent has to OBSERVE.
# Action to take: [2, 14]
# 2
# Tiempo Agente 1  : 0.007445096969604492
# TURNO:  58
# [[3, 23, None], [2, 14, 'anaranjado']]
# Agente 2
# Before executing:
# Action result: None Adversary action: [2, 14, 'anaranjado']
# Agent previous action = [3, 23] Result for that action = None
# Adversary action: 2 Adversary action param: 14 Adversary action result: anaranjado
# Risk level: 4.2
# The agent is at risk and it has to MOVE.
# Action to take: [3, 23]
# 3
# Tiempo Agente 2  : 0.0034487247467041016
# TURNO:  59
# [[3, 23, None], [2, 14, 'anaranjado']]
# PUNTAJE FINAL:  [0, 0]
